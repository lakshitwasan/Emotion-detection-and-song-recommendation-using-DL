# %% [markdown]
# # Loading Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
import os
import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

from keras import regularizers
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils.vis_utils import plot_model

from sklearn.metrics import classification_report, confusion_matrix

main_accent_colour = "#b366ff"
dim_colour="darkgrey"
main_palette = ["#FBE5C0", "#DD9A30", "#F88379", "#FF6FC2", "purple", "#D086F6", "#B0D2C2", "#4C5D70", "#6FA2CE", "#382D24", "#3ACF3A", "#7D7D00"]

# %% [markdown]
# # Analyzing

# %%
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

row = 48
col = 48
classes = len(os.listdir('../input/fer2013/train/'))

# %%
print("Train Set :")

train_count = []
for folder in os.listdir(train_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(train_dir+folder)), "image")
    train_count.append(len(os.listdir(train_dir+folder)))
    
print()

test_count = []
print("Test Set :")
for folder in os.listdir(test_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(test_dir+folder)), "images")
    test_count.append(len(os.listdir(test_dir+folder)))
# Out:
# Train Set :
# surprise folder contains		 3171 image
# fear folder contains		 4097 image
# angry folder contains		 3995 image
# neutral folder contains		 4965 image
# sad folder contains		 4830 image
# disgust folder contains		 436 image
# happy folder contains		 7215 image
#
# Test Set :
# surprise folder contains		 831 images
# fear folder contains		 1024 images
# angry folder contains		 958 images
# neutral folder contains		 1233 images
# sad folder contains		 1247 images
# disgust folder contains		 111 images
# happy folder contains		 1774 images

# %%
vals = ["disgust"]
palette = {c: dim_colour if c not in vals else main_accent_colour for c in os.listdir(train_dir)}

plt.figure(figsize=(8,4))

ax = sns.barplot(y=os.listdir(train_dir),
                 x=train_count,
                 palette=palette,
                 orientation="horizontal",
).set(title='Train Classes')

plt.show()

print()

ax = sns.barplot(y=os.listdir(test_dir),
                 x=test_count,
                 palette=palette,
                 orientation="horizontal",
).set(title='Test Classes')

plt.show()

print()

plt.figure(figsize=(25,25))

i = 1
for folder in os.listdir(train_dir):
    
    img = load_img((train_dir + folder +'/'+ os.listdir(train_dir + folder)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(folder)
    plt.axis('off')
    i += 1
    
plt.show()

# %% [markdown]
# # Preprocessing

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %% [markdown]
# # Model

# %%
def get_model(input_size, classes=7):
    
    model = tf.keras.models.Sequential()   

    model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape =input_size))
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(2, 2))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(classes, activation='softmax'))

    model.compile(optimizer=Adam(lr=0.0001, decay=1e-6), 
                  loss='categorical_crossentropy', 
                  metrics=['accuracy'])
    return model

# %%
fernet = get_model((row,col,1), classes)
fernet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 256)       295168
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 22, 22, 256)       1024
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 256)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              31720448
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 7175
# =================================================================
# Total params: 32,116,743
# Trainable params: 32,116,103
# Non-trainable params: 640
# _________________________________________________________________
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
plot_model(fernet, show_layer_names=True)

# %% [markdown]
# # Checkpoint

# %%
chk_path = 'ferNet.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_accuracy')

earlystop = EarlyStopping(monitor='val_accuracy', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = fernet.fit(x=training_set,
                  validation_data=test_set,
                  epochs=150,
                  callbacks=callbacks,
                  steps_per_epoch=steps_per_epoch,
                  validation_steps=validation_steps)
# Out:
# Epoch 1/150
# 448/448 [==============================] - 48s 98ms/step - loss: 4.2953 - accuracy: 0.2723 - val_loss: 8.1563 - val_accuracy: 0.2121
#
# Epoch 00001: val_loss improved from inf to 8.15626, saving model to ferNet.h5
# Epoch 2/150
# 448/448 [==============================] - 43s 96ms/step - loss: 3.4966 - accuracy: 0.3278 - val_loss: 3.1215 - val_accuracy: 0.3924
#
# Epoch 00002: val_loss improved from 8.15626 to 3.12147, saving model to ferNet.h5
# Epoch 3/150
# 448/448 [==============================] - 43s 96ms/step - loss: 2.9885 - accuracy: 0.3584 - val_loss: 2.6363 - val_accuracy: 0.4293
#
# Epoch 00003: val_loss improved from 3.12147 to 2.63632, saving model to ferNet.h5
# Epoch 4/150
# 448/448 [==============================] - 42s 95ms/step - loss: 2.5691 - accuracy: 0.3879 - val_loss: 2.3055 - val_accuracy: 0.4385
#
# Epoch 00004: val_loss improved from 2.63632 to 2.30553, saving model to ferNet.h5
# Epoch 5/150
# 448/448 [==============================] - 44s 99ms/step - loss: 2.2575 - accuracy: 0.4111 - val_loss: 2.0123 - val_accuracy: 0.4640
#
# Epoch 00005: val_loss improved from 2.30553 to 2.01235, saving model to ferNet.h5
# Epoch 6/150
# 448/448 [==============================] - 44s 98ms/step - loss: 2.0174 - accuracy: 0.4351 - val_loss: 1.8316 - val_accuracy: 0.4775
#
# Epoch 00006: val_loss improved from 2.01235 to 1.83162, saving model to ferNet.h5
# Epoch 7/150
# 448/448 [==============================] - 42s 95ms/step - loss: 1.8337 - accuracy: 0.4576 - val_loss: 1.6982 - val_accuracy: 0.4905
#
# Epoch 00007: val_loss improved from 1.83162 to 1.69822, saving model to ferNet.h5
# Epoch 8/150
# 448/448 [==============================] - 42s 93ms/step - loss: 1.6922 - accuracy: 0.4782 - val_loss: 1.5143 - val_accuracy: 0.5265
#
# Epoch 00008: val_loss improved from 1.69822 to 1.51431, saving model to ferNet.h5
# Epoch 9/150
# 448/448 [==============================] - 42s 95ms/step - loss: 1.5828 - accuracy: 0.4925 - val_loss: 1.4844 - val_accuracy: 0.5223
#
# Epoch 00009: val_loss improved from 1.51431 to 1.48441, saving model to ferNet.h5
# Epoch 10/150
# 448/448 [==============================] - 42s 95ms/step - loss: 1.4868 - accuracy: 0.5109 - val_loss: 1.3602 - val_accuracy: 0.5544
#
# Epoch 00010: val_loss improved from 1.48441 to 1.36018, saving model to ferNet.h5
# Epoch 11/150
# 448/448 [==============================] - 42s 94ms/step - loss: 1.4197 - accuracy: 0.5227 - val_loss: 1.3020 - val_accuracy: 0.5671
#
# Epoch 00011: val_loss improved from 1.36018 to 1.30198, saving model to ferNet.h5
# Epoch 12/150
# 448/448 [==============================] - 45s 100ms/step - loss: 1.3540 - accuracy: 0.5438 - val_loss: 1.2860 - val_accuracy: 0.5675
#
# Epoch 00012: val_loss improved from 1.30198 to 1.28599, saving model to ferNet.h5
# Epoch 13/150
# 448/448 [==============================] - 45s 101ms/step - loss: 1.3067 - accuracy: 0.5566 - val_loss: 1.2326 - val_accuracy: 0.5756
#
# Epoch 00013: val_loss improved from 1.28599 to 1.23261, saving model to ferNet.h5
# Epoch 14/150
# 448/448 [==============================] - 42s 94ms/step - loss: 1.2599 - accuracy: 0.5720 - val_loss: 1.2171 - val_accuracy: 0.5777
#
# Epoch 00014: val_loss improved from 1.23261 to 1.21708, saving model to ferNet.h5
# Epoch 15/150
# 448/448 [==============================] - 42s 93ms/step - loss: 1.2256 - accuracy: 0.5808 - val_loss: 1.1853 - val_accuracy: 0.5912
#
# Epoch 00015: val_loss improved from 1.21708 to 1.18528, saving model to ferNet.h5
# Epoch 16/150
# 448/448 [==============================] - 42s 94ms/step - loss: 1.1914 - accuracy: 0.5907 - val_loss: 1.1724 - val_accuracy: 0.5931
#
# Epoch 00016: val_loss improved from 1.18528 to 1.17237, saving model to ferNet.h5
# Epoch 17/150
# 448/448 [==============================] - 42s 94ms/step - loss: 1.1652 - accuracy: 0.5981 - val_loss: 1.2134 - val_accuracy: 0.5929
#
# Epoch 00017: val_loss did not improve from 1.17237
# Epoch 18/150
# 448/448 [==============================] - 41s 92ms/step - loss: 1.1310 - accuracy: 0.6132 - val_loss: 1.1553 - val_accuracy: 0.6039
#
# Epoch 00018: val_loss improved from 1.17237 to 1.15530, saving model to ferNet.h5
# Epoch 19/150
# 448/448 [==============================] - 43s 95ms/step - loss: 1.1100 - accuracy: 0.6185 - val_loss: 1.1661 - val_accuracy: 0.6023
#
# Epoch 00019: val_loss did not improve from 1.15530
# Epoch 20/150
# 448/448 [==============================] - 43s 95ms/step - loss: 1.0839 - accuracy: 0.6296 - val_loss: 1.1164 - val_accuracy: 0.6184
#
# Epoch 00020: val_loss improved from 1.15530 to 1.11641, saving model to ferNet.h5
# Epoch 21/150
# 448/448 [==============================] - 42s 93ms/step - loss: 1.0555 - accuracy: 0.6389 - val_loss: 1.1132 - val_accuracy: 0.6226
#
# Epoch 00021: val_loss improved from 1.11641 to 1.11315, saving model to ferNet.h5
# Epoch 22/150
# 448/448 [==============================] - 42s 94ms/step - loss: 1.0409 - accuracy: 0.6468 - val_loss: 1.1228 - val_accuracy: 0.6161
#
# Epoch 00022: val_loss did not improve from 1.11315
# Epoch 23/150
# 448/448 [==============================] - 42s 94ms/step - loss: 1.0115 - accuracy: 0.6590 - val_loss: 1.1047 - val_accuracy: 0.6246
#
# Epoch 00023: val_loss improved from 1.11315 to 1.10475, saving model to ferNet.h5
# Epoch 24/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.9904 - accuracy: 0.6641 - val_loss: 1.0983 - val_accuracy: 0.6258
#
# Epoch 00024: val_loss improved from 1.10475 to 1.09827, saving model to ferNet.h5
# Epoch 25/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.9726 - accuracy: 0.6733 - val_loss: 1.1383 - val_accuracy: 0.6225
#
# Epoch 00025: val_loss did not improve from 1.09827
# Epoch 26/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.9492 - accuracy: 0.6822 - val_loss: 1.1201 - val_accuracy: 0.6260
#
# Epoch 00026: val_loss did not improve from 1.09827
# Epoch 27/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.9274 - accuracy: 0.6903 - val_loss: 1.0789 - val_accuracy: 0.6383
#
# Epoch 00027: val_loss improved from 1.09827 to 1.07891, saving model to ferNet.h5
# Epoch 28/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.9159 - accuracy: 0.6909 - val_loss: 1.1021 - val_accuracy: 0.6327
#
# Epoch 00028: val_loss did not improve from 1.07891
# Epoch 29/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.8913 - accuracy: 0.7046 - val_loss: 1.0838 - val_accuracy: 0.6374
#
# Epoch 00029: val_loss did not improve from 1.07891
# Epoch 30/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.8741 - accuracy: 0.7116 - val_loss: 1.1169 - val_accuracy: 0.6346
#
# Epoch 00030: val_loss did not improve from 1.07891
# Epoch 31/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.8598 - accuracy: 0.7151 - val_loss: 1.1395 - val_accuracy: 0.6366
#
# Epoch 00031: val_loss did not improve from 1.07891
# Epoch 32/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.8450 - accuracy: 0.7240 - val_loss: 1.0840 - val_accuracy: 0.6427
#
# Epoch 00032: val_loss did not improve from 1.07891
# Epoch 33/150
# 448/448 [==============================] - 44s 98ms/step - loss: 0.8293 - accuracy: 0.7285 - val_loss: 1.0986 - val_accuracy: 0.6377
#
# Epoch 00033: val_loss did not improve from 1.07891
# Epoch 34/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.8104 - accuracy: 0.7375 - val_loss: 1.1141 - val_accuracy: 0.6456
#
# Epoch 00034: val_loss did not improve from 1.07891
# Epoch 35/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.7938 - accuracy: 0.7389 - val_loss: 1.1338 - val_accuracy: 0.6472
#
# Epoch 00035: val_loss did not improve from 1.07891
# Epoch 36/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.7834 - accuracy: 0.7444 - val_loss: 1.1298 - val_accuracy: 0.6436
#
# Epoch 00036: val_loss did not improve from 1.07891
# Epoch 37/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.7665 - accuracy: 0.7525 - val_loss: 1.1552 - val_accuracy: 0.6511
#
# Epoch 00037: val_loss did not improve from 1.07891
# Epoch 38/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7515 - accuracy: 0.7562 - val_loss: 1.1755 - val_accuracy: 0.6465
#
# Epoch 00038: val_loss did not improve from 1.07891
# Epoch 39/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7382 - accuracy: 0.7634 - val_loss: 1.1496 - val_accuracy: 0.6539
#
# Epoch 00039: val_loss did not improve from 1.07891
# Epoch 40/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.7244 - accuracy: 0.7683 - val_loss: 1.2207 - val_accuracy: 0.6355
#
# Epoch 00040: val_loss did not improve from 1.07891
# Epoch 41/150
# 448/448 [==============================] - 44s 98ms/step - loss: 0.7150 - accuracy: 0.7727 - val_loss: 1.1644 - val_accuracy: 0.6402
#
# Epoch 00041: val_loss did not improve from 1.07891
# Epoch 42/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.7101 - accuracy: 0.7723 - val_loss: 1.1472 - val_accuracy: 0.6505
#
# Epoch 00042: val_loss did not improve from 1.07891
# Epoch 43/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.6967 - accuracy: 0.7779 - val_loss: 1.1479 - val_accuracy: 0.6487
#
# Epoch 00043: val_loss did not improve from 1.07891
# Epoch 44/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6793 - accuracy: 0.7857 - val_loss: 1.1999 - val_accuracy: 0.6503
#
# Epoch 00044: val_loss did not improve from 1.07891
# Epoch 45/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.6651 - accuracy: 0.7901 - val_loss: 1.1799 - val_accuracy: 0.6586
#
# Epoch 00045: val_loss did not improve from 1.07891
# Epoch 46/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.6648 - accuracy: 0.7926 - val_loss: 1.1499 - val_accuracy: 0.6558
#
# Epoch 00046: val_loss did not improve from 1.07891
# Epoch 47/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.6540 - accuracy: 0.7944 - val_loss: 1.2289 - val_accuracy: 0.6412
#
# Epoch 00047: val_loss did not improve from 1.07891
# Epoch 48/150
# 448/448 [==============================] - 44s 99ms/step - loss: 0.6436 - accuracy: 0.7979 - val_loss: 1.2175 - val_accuracy: 0.6496
#
# Epoch 00048: val_loss did not improve from 1.07891
# Epoch 49/150
# 448/448 [==============================] - 45s 100ms/step - loss: 0.6313 - accuracy: 0.8019 - val_loss: 1.2151 - val_accuracy: 0.6412
#
# Epoch 00049: val_loss did not improve from 1.07891
# Epoch 50/150
# 448/448 [==============================] - 44s 99ms/step - loss: 0.6286 - accuracy: 0.8019 - val_loss: 1.2280 - val_accuracy: 0.6509
#
# Epoch 00050: val_loss did not improve from 1.07891
# Epoch 51/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.6115 - accuracy: 0.8093 - val_loss: 1.2031 - val_accuracy: 0.6543
#
# Epoch 00051: val_loss did not improve from 1.07891
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# Epoch 52/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.5654 - accuracy: 0.8285 - val_loss: 1.1969 - val_accuracy: 0.6575
#
# Epoch 00052: val_loss did not improve from 1.07891
# Epoch 53/150
# 448/448 [==============================] - 44s 98ms/step - loss: 0.5364 - accuracy: 0.8382 - val_loss: 1.2149 - val_accuracy: 0.6596
#
# Epoch 00053: val_loss did not improve from 1.07891
# Epoch 54/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.5227 - accuracy: 0.8422 - val_loss: 1.2105 - val_accuracy: 0.6628
#
# Epoch 00054: val_loss did not improve from 1.07891
# Epoch 55/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.5207 - accuracy: 0.8431 - val_loss: 1.2286 - val_accuracy: 0.6656
#
# Epoch 00055: val_loss did not improve from 1.07891
# Epoch 56/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.5121 - accuracy: 0.8472 - val_loss: 1.2028 - val_accuracy: 0.6639
#
# Epoch 00056: val_loss did not improve from 1.07891
# Epoch 57/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.5071 - accuracy: 0.8463 - val_loss: 1.2049 - val_accuracy: 0.6620
#
# Epoch 00057: val_loss did not improve from 1.07891
# Epoch 58/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4955 - accuracy: 0.8502 - val_loss: 1.2173 - val_accuracy: 0.6648
#
# Epoch 00058: val_loss did not improve from 1.07891
# Epoch 59/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.4916 - accuracy: 0.8511 - val_loss: 1.2098 - val_accuracy: 0.6699
#
# Epoch 00059: val_loss did not improve from 1.07891
# Epoch 60/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4850 - accuracy: 0.8562 - val_loss: 1.2376 - val_accuracy: 0.6599
#
# Epoch 00060: val_loss did not improve from 1.07891
# Epoch 61/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4780 - accuracy: 0.8564 - val_loss: 1.2344 - val_accuracy: 0.6662
#
# Epoch 00061: val_loss did not improve from 1.07891
# Epoch 62/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.4751 - accuracy: 0.8593 - val_loss: 1.2213 - val_accuracy: 0.6678
#
# Epoch 00062: val_loss did not improve from 1.07891
# Epoch 63/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4664 - accuracy: 0.8595 - val_loss: 1.2249 - val_accuracy: 0.6664
#
# Epoch 00063: val_loss did not improve from 1.07891
# Epoch 64/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4697 - accuracy: 0.8613 - val_loss: 1.2529 - val_accuracy: 0.6695
#
# Epoch 00064: val_loss did not improve from 1.07891
# Epoch 65/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4618 - accuracy: 0.8626 - val_loss: 1.2387 - val_accuracy: 0.6676
#
# Epoch 00065: val_loss did not improve from 1.07891
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# Epoch 66/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.4547 - accuracy: 0.8662 - val_loss: 1.2463 - val_accuracy: 0.6677
#
# Epoch 00066: val_loss did not improve from 1.07891
# Epoch 67/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4422 - accuracy: 0.8700 - val_loss: 1.2517 - val_accuracy: 0.6681
#
# Epoch 00067: val_loss did not improve from 1.07891
# Epoch 68/150
# 448/448 [==============================] - 44s 98ms/step - loss: 0.4468 - accuracy: 0.8676 - val_loss: 1.2433 - val_accuracy: 0.6692
#
# Epoch 00068: val_loss did not improve from 1.07891
# Epoch 69/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4461 - accuracy: 0.8664 - val_loss: 1.2485 - val_accuracy: 0.6674
#
# Epoch 00069: val_loss did not improve from 1.07891
# Epoch 70/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4354 - accuracy: 0.8725 - val_loss: 1.2472 - val_accuracy: 0.6687
#
# Epoch 00070: val_loss did not improve from 1.07891
# Epoch 71/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4379 - accuracy: 0.8695 - val_loss: 1.2463 - val_accuracy: 0.6680
#
# Epoch 00071: val_loss did not improve from 1.07891
#
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# Epoch 72/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.4364 - accuracy: 0.8710 - val_loss: 1.2450 - val_accuracy: 0.6692
#
# Epoch 00072: val_loss did not improve from 1.07891
# Epoch 73/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.4328 - accuracy: 0.8725 - val_loss: 1.2500 - val_accuracy: 0.6682
#
# Epoch 00073: val_loss did not improve from 1.07891
# Epoch 74/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4314 - accuracy: 0.8727 - val_loss: 1.2509 - val_accuracy: 0.6685
#
# Epoch 00074: val_loss did not improve from 1.07891
# Epoch 75/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4318 - accuracy: 0.8719 - val_loss: 1.2510 - val_accuracy: 0.6677
#
# Epoch 00075: val_loss did not improve from 1.07891
# Epoch 76/150
# 448/448 [==============================] - 45s 100ms/step - loss: 0.4284 - accuracy: 0.8736 - val_loss: 1.2495 - val_accuracy: 0.6684
#
# Epoch 00076: val_loss did not improve from 1.07891
# Epoch 77/150
# 448/448 [==============================] - 44s 99ms/step - loss: 0.4407 - accuracy: 0.8701 - val_loss: 1.2512 - val_accuracy: 0.6687
#
# Epoch 00077: val_loss did not improve from 1.07891
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# Epoch 78/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4304 - accuracy: 0.8737 - val_loss: 1.2488 - val_accuracy: 0.6688
#
# Epoch 00078: val_loss did not improve from 1.07891
# Epoch 79/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4337 - accuracy: 0.8723 - val_loss: 1.2507 - val_accuracy: 0.6692
#
# Epoch 00079: val_loss did not improve from 1.07891
# Epoch 80/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4378 - accuracy: 0.8714 - val_loss: 1.2507 - val_accuracy: 0.6692
#
# Epoch 00080: val_loss did not improve from 1.07891
# Epoch 81/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4367 - accuracy: 0.8703 - val_loss: 1.2490 - val_accuracy: 0.6685
#
# Epoch 00081: val_loss did not improve from 1.07891
# Epoch 82/150
# 448/448 [==============================] - 44s 99ms/step - loss: 0.4301 - accuracy: 0.8756 - val_loss: 1.2523 - val_accuracy: 0.6684
#
# Epoch 00082: val_loss did not improve from 1.07891
# Epoch 83/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.4333 - accuracy: 0.8722 - val_loss: 1.2528 - val_accuracy: 0.6680
#
# Epoch 00083: val_loss did not improve from 1.07891
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# Epoch 84/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4314 - accuracy: 0.8720 - val_loss: 1.2513 - val_accuracy: 0.6680
#
# Epoch 00084: val_loss did not improve from 1.07891
# Epoch 85/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4301 - accuracy: 0.8730 - val_loss: 1.2508 - val_accuracy: 0.6682
#
# Epoch 00085: val_loss did not improve from 1.07891
# Epoch 86/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4327 - accuracy: 0.8733 - val_loss: 1.2527 - val_accuracy: 0.6678
#
# Epoch 00086: val_loss did not improve from 1.07891
# Epoch 87/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.4329 - accuracy: 0.8730 - val_loss: 1.2510 - val_accuracy: 0.6682
#
# Epoch 00087: val_loss did not improve from 1.07891
# Epoch 88/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4272 - accuracy: 0.8760 - val_loss: 1.2531 - val_accuracy: 0.6678
#
# Epoch 00088: val_loss did not improve from 1.07891
# Epoch 89/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4358 - accuracy: 0.8702 - val_loss: 1.2515 - val_accuracy: 0.6673
#
# Epoch 00089: val_loss did not improve from 1.07891
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 6.399999818995639e-09.
# Epoch 90/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4307 - accuracy: 0.8726 - val_loss: 1.2510 - val_accuracy: 0.6676
#
# Epoch 00090: val_loss did not improve from 1.07891
# Epoch 91/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4325 - accuracy: 0.8708 - val_loss: 1.2499 - val_accuracy: 0.6681
#
# Epoch 00091: val_loss did not improve from 1.07891
# Epoch 92/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4279 - accuracy: 0.8756 - val_loss: 1.2504 - val_accuracy: 0.6684
#
# Epoch 00092: val_loss did not improve from 1.07891
# Epoch 93/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.4345 - accuracy: 0.8728 - val_loss: 1.2511 - val_accuracy: 0.6676
#
# Epoch 00093: val_loss did not improve from 1.07891
# Epoch 94/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.4300 - accuracy: 0.8710 - val_loss: 1.2514 - val_accuracy: 0.6684
#
# Epoch 00094: val_loss did not improve from 1.07891
# Epoch 95/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4362 - accuracy: 0.8701 - val_loss: 1.2503 - val_accuracy: 0.6680
#
# Epoch 00095: val_loss did not improve from 1.07891
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 1.279999928271991e-09.
# Epoch 96/150
# 448/448 [==============================] - 48s 107ms/step - loss: 0.4328 - accuracy: 0.8729 - val_loss: 1.2504 - val_accuracy: 0.6681
#
# Epoch 00096: val_loss did not improve from 1.07891
# Epoch 97/150
# 448/448 [==============================] - 47s 105ms/step - loss: 0.4320 - accuracy: 0.8741 - val_loss: 1.2512 - val_accuracy: 0.6674
#
# Epoch 00097: val_loss did not improve from 1.07891
# Epoch 98/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4357 - accuracy: 0.8729 - val_loss: 1.2499 - val_accuracy: 0.6684
#
# Epoch 00098: val_loss did not improve from 1.07891
# Epoch 99/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.4378 - accuracy: 0.8715 - val_loss: 1.2508 - val_accuracy: 0.6678
#
# Epoch 00099: val_loss did not improve from 1.07891
# Epoch 100/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4342 - accuracy: 0.8722 - val_loss: 1.2519 - val_accuracy: 0.6678
#
# Epoch 00100: val_loss did not improve from 1.07891
# Epoch 101/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4330 - accuracy: 0.8745 - val_loss: 1.2519 - val_accuracy: 0.6684
#
# Epoch 00101: val_loss did not improve from 1.07891
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 2.55999976772614e-10.
# Epoch 102/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4344 - accuracy: 0.8752 - val_loss: 1.2515 - val_accuracy: 0.6677
#
# Epoch 00102: val_loss did not improve from 1.07891
# Epoch 103/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4368 - accuracy: 0.8711 - val_loss: 1.2517 - val_accuracy: 0.6678
#
# Epoch 00103: val_loss did not improve from 1.07891
# Epoch 104/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4288 - accuracy: 0.8746 - val_loss: 1.2516 - val_accuracy: 0.6681
#
# Epoch 00104: val_loss did not improve from 1.07891
# Epoch 105/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4336 - accuracy: 0.8697 - val_loss: 1.2518 - val_accuracy: 0.6676
#
# Epoch 00105: val_loss did not improve from 1.07891
# Epoch 106/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4375 - accuracy: 0.8727 - val_loss: 1.2522 - val_accuracy: 0.6674
#
# Epoch 00106: val_loss did not improve from 1.07891
# Epoch 107/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4296 - accuracy: 0.8743 - val_loss: 1.2524 - val_accuracy: 0.6684
#
# Epoch 00107: val_loss did not improve from 1.07891
#
# Epoch 00107: ReduceLROnPlateau reducing learning rate to 5.119999424429978e-11.
# Epoch 108/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4338 - accuracy: 0.8699 - val_loss: 1.2521 - val_accuracy: 0.6680
#
# Epoch 00108: val_loss did not improve from 1.07891
# Epoch 109/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4302 - accuracy: 0.8739 - val_loss: 1.2522 - val_accuracy: 0.6681
#
# Epoch 00109: val_loss did not improve from 1.07891
# Epoch 110/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4375 - accuracy: 0.8687 - val_loss: 1.2506 - val_accuracy: 0.6682
#
# Epoch 00110: val_loss did not improve from 1.07891
# Epoch 111/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4294 - accuracy: 0.8748 - val_loss: 1.2503 - val_accuracy: 0.6678
#
# Epoch 00111: val_loss did not improve from 1.07891
# Epoch 112/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4358 - accuracy: 0.8721 - val_loss: 1.2522 - val_accuracy: 0.6674
#
# Epoch 00112: val_loss did not improve from 1.07891
# Epoch 113/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4293 - accuracy: 0.8717 - val_loss: 1.2520 - val_accuracy: 0.6682
#
# Epoch 00113: val_loss did not improve from 1.07891
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 1.0239999126415712e-11.
# Epoch 114/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.4311 - accuracy: 0.8731 - val_loss: 1.2523 - val_accuracy: 0.6676
#
# Epoch 00114: val_loss did not improve from 1.07891
# Epoch 115/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4313 - accuracy: 0.8728 - val_loss: 1.2515 - val_accuracy: 0.6678
#
# Epoch 00115: val_loss did not improve from 1.07891
# Epoch 116/150
# 448/448 [==============================] - 45s 100ms/step - loss: 0.4334 - accuracy: 0.8719 - val_loss: 1.2510 - val_accuracy: 0.6687
#
# Epoch 00116: val_loss did not improve from 1.07891
# Epoch 117/150
# 448/448 [==============================] - 44s 99ms/step - loss: 0.4313 - accuracy: 0.8718 - val_loss: 1.2516 - val_accuracy: 0.6681
#
# Epoch 00117: val_loss did not improve from 1.07891
# Epoch 118/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4345 - accuracy: 0.8740 - val_loss: 1.2516 - val_accuracy: 0.6677
#
# Epoch 00118: val_loss did not improve from 1.07891
# Epoch 119/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4351 - accuracy: 0.8696 - val_loss: 1.2511 - val_accuracy: 0.6681
#
# Epoch 00119: val_loss did not improve from 1.07891
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 2.0479997905886727e-12.
# Epoch 120/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4311 - accuracy: 0.8740 - val_loss: 1.2509 - val_accuracy: 0.6678
#
# Epoch 00120: val_loss did not improve from 1.07891
# Epoch 121/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4345 - accuracy: 0.8743 - val_loss: 1.2515 - val_accuracy: 0.6684
#
# Epoch 00121: val_loss did not improve from 1.07891
# Epoch 122/150
# 448/448 [==============================] - 46s 102ms/step - loss: 0.4372 - accuracy: 0.8712 - val_loss: 1.2513 - val_accuracy: 0.6680
#
# Epoch 00122: val_loss did not improve from 1.07891
# Epoch 123/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4313 - accuracy: 0.8731 - val_loss: 1.2513 - val_accuracy: 0.6681
#
# Epoch 00123: val_loss did not improve from 1.07891
# Epoch 124/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.4345 - accuracy: 0.8724 - val_loss: 1.2516 - val_accuracy: 0.6674
#
# Epoch 00124: val_loss did not improve from 1.07891
# Epoch 125/150
# 448/448 [==============================] - 42s 93ms/step - loss: 0.4342 - accuracy: 0.8709 - val_loss: 1.2514 - val_accuracy: 0.6678
#
# Epoch 00125: val_loss did not improve from 1.07891
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 4.0959995811773456e-13.
# Epoch 126/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4289 - accuracy: 0.8727 - val_loss: 1.2528 - val_accuracy: 0.6682
#
# Epoch 00126: val_loss did not improve from 1.07891
# Epoch 127/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4310 - accuracy: 0.8718 - val_loss: 1.2524 - val_accuracy: 0.6677
#
# Epoch 00127: val_loss did not improve from 1.07891
# Epoch 128/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4338 - accuracy: 0.8721 - val_loss: 1.2506 - val_accuracy: 0.6682
#
# Epoch 00128: val_loss did not improve from 1.07891
# Epoch 129/150
# 448/448 [==============================] - 44s 97ms/step - loss: 0.4341 - accuracy: 0.8728 - val_loss: 1.2525 - val_accuracy: 0.6678
#
# Epoch 00129: val_loss did not improve from 1.07891
# Epoch 130/150
# 448/448 [==============================] - 44s 98ms/step - loss: 0.4342 - accuracy: 0.8736 - val_loss: 1.2521 - val_accuracy: 0.6677
#
# Epoch 00130: val_loss did not improve from 1.07891
# Epoch 131/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4333 - accuracy: 0.8715 - val_loss: 1.2522 - val_accuracy: 0.6677
#
# Epoch 00131: val_loss did not improve from 1.07891
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 8.191999053934474e-14.
# Epoch 132/150
# 448/448 [==============================] - 41s 92ms/step - loss: 0.4324 - accuracy: 0.8760 - val_loss: 1.2515 - val_accuracy: 0.6676
#
# Epoch 00132: val_loss did not improve from 1.07891
# Epoch 133/150
# 448/448 [==============================] - 42s 95ms/step - loss: 0.4389 - accuracy: 0.8710 - val_loss: 1.2501 - val_accuracy: 0.6680
#
# Epoch 00133: val_loss did not improve from 1.07891
# Epoch 134/150
# 448/448 [==============================] - 43s 96ms/step - loss: 0.4346 - accuracy: 0.8715 - val_loss: 1.2519 - val_accuracy: 0.6681
#
# Epoch 00134: val_loss did not improve from 1.07891
# Epoch 135/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4348 - accuracy: 0.8707 - val_loss: 1.2531 - val_accuracy: 0.6676
#
# Epoch 00135: val_loss did not improve from 1.07891
# Epoch 136/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4311 - accuracy: 0.8746 - val_loss: 1.2512 - val_accuracy: 0.6678
#
# Epoch 00136: val_loss did not improve from 1.07891
# Epoch 137/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4367 - accuracy: 0.8734 - val_loss: 1.2524 - val_accuracy: 0.6681
#
# Epoch 00137: val_loss did not improve from 1.07891
#
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 1.638399837891949e-14.
# Epoch 138/150
# 448/448 [==============================] - 42s 94ms/step - loss: 0.4362 - accuracy: 0.8701 - val_loss: 1.2519 - val_accuracy: 0.6680
#
# Epoch 00138: val_loss did not improve from 1.07891
# Epoch 139/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4328 - accuracy: 0.8714 - val_loss: 1.2520 - val_accuracy: 0.6681
#
# Epoch 00139: val_loss did not improve from 1.07891
# Epoch 140/150
# 448/448 [==============================] - 43s 97ms/step - loss: 0.4338 - accuracy: 0.8714 - val_loss: 1.2489 - val_accuracy: 0.6685
#
# Epoch 00140: val_loss did not improve from 1.07891
# Epoch 141/150
# 448/448 [==============================] - 43s 95ms/step - loss: 0.4322 - accuracy: 0.8744 - val_loss: 1.2507 - val_accuracy: 0.6685
#
# Epoch 00141: val_loss did not improve from 1.07891
# Epoch 142/150
# 448/448 [==============================] - 45s 101ms/step - loss: 0.4297 - accuracy: 0.8724 - val_loss: 1.2517 - val_accuracy: 0.6684
#
# Epoch 00142: val_loss did not improve from 1.07891
# Epoch 143/150
# 448/448 [==============================] - 49s 110ms/step - loss: 0.4355 - accuracy: 0.8718 - val_loss: 1.2508 - val_accuracy: 0.6680
#
# Epoch 00143: val_loss did not improve from 1.07891
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 3.27679981130917e-15.
# Epoch 144/150
# 448/448 [==============================] - 50s 111ms/step - loss: 0.4269 - accuracy: 0.8753 - val_loss: 1.2491 - val_accuracy: 0.6680
#
# Epoch 00144: val_loss did not improve from 1.07891
# Epoch 145/150
# 448/448 [==============================] - 47s 104ms/step - loss: 0.4368 - accuracy: 0.8700 - val_loss: 1.2521 - val_accuracy: 0.6677
#
# Epoch 00145: val_loss did not improve from 1.07891
# Epoch 146/150
# 448/448 [==============================] - 55s 123ms/step - loss: 0.4402 - accuracy: 0.8687 - val_loss: 1.2517 - val_accuracy: 0.6681
#
# Epoch 00146: val_loss did not improve from 1.07891
# Epoch 147/150
# 448/448 [==============================] - 47s 104ms/step - loss: 0.4283 - accuracy: 0.8735 - val_loss: 1.2509 - val_accuracy: 0.6678
#
# Epoch 00147: val_loss did not improve from 1.07891
# Epoch 148/150
# 448/448 [==============================] - 46s 104ms/step - loss: 0.4282 - accuracy: 0.8735 - val_loss: 1.2522 - val_accuracy: 0.6678
#
# Epoch 00148: val_loss did not improve from 1.07891
# Epoch 149/150
# 448/448 [==============================] - 47s 105ms/step - loss: 0.4281 - accuracy: 0.8740 - val_loss: 1.2498 - val_accuracy: 0.6676
#
# Epoch 00149: val_loss did not improve from 1.07891
#
# Epoch 00149: ReduceLROnPlateau reducing learning rate to 6.553599792024929e-16.
# Epoch 150/150
# 448/448 [==============================] - 48s 107ms/step - loss: 0.4266 - accuracy: 0.8734 - val_loss: 1.2507 - val_accuracy: 0.6680
#
# Epoch 00150: val_loss did not improve from 1.07891

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

# %%
train_loss, train_accu = fernet.evaluate(training_set)
test_loss, test_accu = fernet.evaluate(test_set)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 40s 89ms/step - loss: 0.2599 - accuracy: 0.9462
# 113/113 [==============================] - 7s 64ms/step - loss: 1.2502 - accuracy: 0.6680
# final train accuracy = 94.62 , validation accuracy = 66.80

# %% [markdown]
# # Result

# %%
y_pred = fernet.predict(training_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

cm_train = confusion_matrix(training_set.classes, y_pred)
print('Confusion Matrix')
print(cm_train)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(training_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_train, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[ 546   49  552 1025  723  667  433]
#  [  76    8   61  113   65   65   48]
#  [ 576   63  542 1038  731  703  444]
#  [ 955  104  956 1852 1300 1227  821]
#  [ 683   82  687 1244  838  873  558]
#  [ 661   65  675 1225  855  799  550]
#  [ 438   52  474  826  557  496  328]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14      3995
#      disgust       0.02      0.02      0.02       436
#         fear       0.14      0.13      0.13      4097
#        happy       0.25      0.26      0.25      7215
#      neutral       0.17      0.17      0.17      4965
#          sad       0.17      0.17      0.17      4830
#     surprise       0.10      0.10      0.10      3171
#
#     accuracy                           0.17     28709
#    macro avg       0.14      0.14      0.14     28709
# weighted avg       0.17      0.17      0.17     28709

# %%
y_pred = fernet.predict(test_set)
y_pred = np.argmax(y_pred, axis=1)
class_labels = test_set.class_indices
class_labels = {v:k for k,v in class_labels.items()}

cm_test = confusion_matrix(test_set.classes, y_pred)
print('Confusion Matrix')
print(cm_test)
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(test_set.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
plt.imshow(cm_test, interpolation='nearest')
plt.colorbar()
tick_mark = np.arange(len(target_names))
_ = plt.xticks(tick_mark, target_names, rotation=90)
_ = plt.yticks(tick_mark, target_names)
# Out:
# Confusion Matrix
# [[137   7 109 228 179 173 125]
#  [ 14   1  16  28  16  20  16]
#  [138  13 113 249 197 192 122]
#  [262  28 221 402 335 333 193]
#  [181  11 158 293 223 223 144]
#  [172   5 142 335 238 226 129]
#  [110   9  89 227 169 130  97]]
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.14      0.14      0.14       958
#      disgust       0.01      0.01      0.01       111
#         fear       0.13      0.11      0.12      1024
#        happy       0.23      0.23      0.23      1774
#      neutral       0.16      0.18      0.17      1233
#          sad       0.17      0.18      0.18      1247
#     surprise       0.12      0.12      0.12       831
#
#     accuracy                           0.17      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.17      0.17      0.17      7178

# %% [markdown]
# # Recommending Music

# %%
mood_music = pd.read_csv("../input/spotify-music-data-to-identify-the-moods/data_moods.csv")
mood_music = mood_music[['name','artist','mood']]
mood_music.head()
# Out:
#                                           name          artist       mood
# 0                                         1999          Prince      Happy
# 1                                           23  Blonde Redhead        Sad
# 2                                     9 Crimes     Damien Rice        Sad
# 3                               99 Luftballons            Nena      Happy
# 4  A Boy Brushed Red Living In Black And White       Underoath  Energetic

# %%
image = cv2.imread('../input/fer2013/test/happy/PrivateTest_10077120.jpg',cv2.IMREAD_GRAYSCALE)

plt.imshow(image,cmap='gray')
plt.show()

# %%
image = cv2.resize(image,(48,48))
img=np.array(image)
img=img.reshape(1,48,48,1)
predict_x=fernet.predict(img) 
result=np.argmax(predict_x,axis=1)
result[0]
# Out:
# 3

# %%
if(result[0]==0 or result[0]==1 or result[0]==2 ):
    #for angery,disgust,fear
    filter1=mood_music['mood']=='Calm'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
if(result[0]==3 or result[0]==4):
    #for happy, neutral
    filter1=mood_music['mood']=='Happy'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
if(result[0]==5):
       #for Sad
    filter1=mood_music['mood']=='Sad'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
if(result[0]==6):
     #for surprise
    filter1=mood_music['mood']=='Energetic'
    f1=mood_music.where(filter1)
    f1=f1.dropna()
    f2 =f1.sample(n=5)
    f2.reset_index(inplace=True)
    display(f2)
# Out:
#    index                                     name                    artist  \
# 0    207                     Geno - 2000 Remaster    Dexys Midnight Runners
# 1    260                                      ID8  Dimitri Vangelis & Wyman
# 2    590                              Two Princes              Spin Doctors
# 3    652   Wonderful Together (feat. Envy Monroe)               Blasterjaxx
# 4    624  We Are Your Friends - Justice Vs Simian                    Simian
#
#     mood
# 0  Happy
# 1  Happy
# 2  Happy
# 3  Happy
# 4  Happy
